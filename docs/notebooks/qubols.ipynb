# %%
from qalcore.dwave.qubols.encodings import  EfficientEncoding
import matplotlib.pyplot as  plt
quantum_solver_options = {'num_reads':100, 'num_qbits':21, 'encoding': EfficientEncoding}

# %%
from scipy.sparse import random as sprand 
import numpy as np 

A = 0.5*sprand(5,5, density=0.8, format='csr')
b = 0.1*np.random.rand(5)

# %%
ref = np.linalg.solve(A.todense(),b)
ref
# Out:
# array([ 0.40490949,  0.47735498, -0.54651695,  0.09965334,  0.32967986])

# %%
from quantum_newton_raphson.qubo_solve import QUBO_SOLVER
solver = QUBO_SOLVER(num_reads=100, num_qbits=11, encoding=EfficientEncoding)
res = solver(A, b)

# %%
plt.plot([-1,1],[-1,1],'--')
plt.scatter(res.solution,ref)

# %%
from qalcore.dwave.qubols.qubols import QUBOLS 
sol = QUBOLS({'encoding':EfficientEncoding}).solve(A, b)

# %%
plt.plot([-1,1],[-1,1],'--')
plt.scatter(sol, ref)
